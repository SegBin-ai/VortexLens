# %%
# !ls
# %cd VortexLens/Weld-quality-inspection-9
# !ls

# !ls

# !yolo task=detect mode=train model=yolov8s.pt data=data.yaml epochs=5 imgsz=640
# Out:
# README.dataset.txt  data.yaml           test                valid
# README.roboflow.txt runs                train               yolov8s.pt
# [Errno 2] No such file or directory: 'VortexLens/Weld-quality-inspection-9'
# /Users/aadityavoruganti/Desktop/Aadi/TerraVortex/VortexLens/Weld-quality-inspection-9
# README.dataset.txt  data.yaml           test                valid
# README.roboflow.txt runs                train               yolov8s.pt
# README.dataset.txt  data.yaml           test                valid
# README.roboflow.txt runs                train               yolov8s.pt
# New https://pypi.org/project/ultralytics/8.2.19 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.18 🚀 Python-3.11.7 torch-2.2.1 CPU (Intel Core(TM) i9-9880H 2.30GHz)
# ...
